# %% [markdown]
# ## # Machine Learning - Anomaly Detection - DBScan Clustering

# %% [markdown]
# ### Step-01: Import all the libraries required to perform Anomaly Detection by using DBScan Clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step-02: Import make_circles from sklearn.datasets

# %%
from sklearn.datasets import make_circles

# %%
x,y = make_circles(n_samples = 750, factor = 0.2, noise = 0.1, random_state = 100)

# %%
x
# Out:
# array([[-0.03894193, -0.05293772],
#        [-0.37570418,  0.93190121],
#        [-0.25382885,  0.05127261],
#        ...,
#        [ 0.87842913, -0.27604257],
#        [ 0.25966667,  0.92738398],
#        [-0.17282338, -0.02783937]])

# %% [markdown]
# ### Step-03: Import DBSCAN from sklearn.cluster

# %%
from sklearn.cluster import DBSCAN

# %%
sns.scatterplot(x = x[:,0], y = x[:,1])
plt.xlabel("Feature_01")
plt.ylabel("Feature_02")
plt.title("Feature_01 v/s Feature_02")
# Out:
# Text(0.5, 1.0, 'Feature_01 v/s Feature_02')

# %%
db_scan = DBSCAN(eps = 0.1)

# %%
db_scan.fit(x)
# Out:
# DBSCAN(eps=0.1)

# %%
db_scan.fit_predict(x)
# Out:
# array([ 0,  1,  0,  2,  0,  0,  3,  0,  0,  0,  0,  0,  4,  0,  0,  0,  0,
#         0, -1,  5,  1,  6,  2,  6,  7,  0,  0,  3,  9,  0,  4,  1,  0,  2,
#         4,  1,  6,  7,  6,  0,  4,  0,  0, -1,  5,  0,  0,  6,  8,  4,  6,
#         0, -1,  2,  4,  1, -1,  0,  0,  4,  4,  0,  1,  4,  4,  0,  0,  0,
#         4,  4,  0,  8, -1,  0,  6, -1,  0,  4,  4,  0,  0,  0,  0,  4,  4,
#         1,  0,  0, -1,  0,  7,  0,  0,  0,  0,  0, -1,  1,  1,  6,  9,  4,
#         0,  0,  9,  0,  0,  9,  4,  0,  3,  0,  0,  3,  0,  0,  0,  3,  0,
#         6,  2,  0,  0,  4,  0,  4,  0,  7,  0,  1, -1,  6,  4,  0,  0,  1,
#         0,  3,  0,  4,  0,  6,  0,  1,  3,  9,  2,  5,  0,  0,  4,  1,  7,
#         0,  9,  0,  0,  0,  0,  4,  2,  8,  0, -1,  0,  0,  0,  0,  0,  7,
#         0,  0,  2,  0,  9,  4,  0,  4,  0, -1,  0,  0, -1,  0,  4, -1,  6,
#         0,  0,  0,  8, -1,  0,  0, -1,  0,  4,  0,  4,  0,  0,  0,  8,  4,
# ...

# %%
x_labels = db_scan.labels_

# %%
x_labels
# Out:
# array([ 0,  1,  0,  2,  0,  0,  3,  0,  0,  0,  0,  0,  4,  0,  0,  0,  0,
#         0, -1,  5,  1,  6,  2,  6,  7,  0,  0,  3,  9,  0,  4,  1,  0,  2,
#         4,  1,  6,  7,  6,  0,  4,  0,  0, -1,  5,  0,  0,  6,  8,  4,  6,
#         0, -1,  2,  4,  1, -1,  0,  0,  4,  4,  0,  1,  4,  4,  0,  0,  0,
#         4,  4,  0,  8, -1,  0,  6, -1,  0,  4,  4,  0,  0,  0,  0,  4,  4,
#         1,  0,  0, -1,  0,  7,  0,  0,  0,  0,  0, -1,  1,  1,  6,  9,  4,
#         0,  0,  9,  0,  0,  9,  4,  0,  3,  0,  0,  3,  0,  0,  0,  3,  0,
#         6,  2,  0,  0,  4,  0,  4,  0,  7,  0,  1, -1,  6,  4,  0,  0,  1,
#         0,  3,  0,  4,  0,  6,  0,  1,  3,  9,  2,  5,  0,  0,  4,  1,  7,
#         0,  9,  0,  0,  0,  0,  4,  2,  8,  0, -1,  0,  0,  0,  0,  0,  7,
#         0,  0,  2,  0,  9,  4,  0,  4,  0, -1,  0,  0, -1,  0,  4, -1,  6,
#         0,  0,  0,  8, -1,  0,  0, -1,  0,  4,  0,  4,  0,  0,  0,  8,  4,
# ...

# %%
sns.scatterplot(x = x[:,0], y = x[:,1], hue = x_labels)
plt.xlabel("Feature_01")
plt.ylabel("Feature_02")
plt.title("Feature_01 v/s Feature_02")
# Out:
# Text(0.5, 1.0, 'Feature_01 v/s Feature_02')
